# %%
import pandas as pd

# %%
df = pd.read_csv('선호프로그램종합.csv')

# %%
df
# Out:
#     rank      name  channel category day    time
# 0      1      미스트롯     TV조선       예능   목  2200.0
# 1      2    고려거란전쟁     KBS2      드라마  토일  2115.0
# 2      3     나혼자산다      MBC       예능   금  2310.0
# 3      4  내남편과결혼해줘      tvN      드라마  월화  2050.0
# 4      5    웰컴투삼달리      tvN       예능  토일  2230.0
# ..   ...       ...      ...      ...  ..     ...
# 75     6      1박2일      KBS       예능   일  1810.0
# 76     7   나는자연인이다      MBN    시사/교양   수  2110.0
# 77     8       런닝맨      SBS       예능   일  1810.0
# 78     9      나는솔로  SBSPLUS       예능   수  2230.0
# 79    10    미운우리새끼      SBS       예능   일  2105.0
#
# [80 rows x 6 columns]

# %%
df.groupby(['rank','channel'])['channel'].count()
# Out:
# rank  channel
# 1     MBC        2
#       SBS        1
#       TV조선       2
#       tvN        3
# 2     KBS2       4
#       MBC        1
#       SBS        1
#       TV조선       1
#       tvN        1
# 3     KBS        1
#       KBS1       1
#       KBS2       1
#       MBC        4
#       SBS        1
# 4     KBS        1
#       KBS2       2
#       SBS        2
#       tvN        3
# 5     JTBC       1
#       KBS1       1
#       MBC        1
#       MBN        2
#       tvN        3
# 6     KBS        1
#       MBC        1
#       MBN        3
#       NETFLIX    1
#       SBS        1
#       tvN        1
# 7     KBS1       1
#       MBC        1
#       MBN        2
#       SBS        2
#       TV조선       1
#       tvN        1
# 8     KBS2       2
#       MBC        1
#       MBN        1
#       SBS        2
#       tvN        2
# 9     JTBC       2
#       KBS1       2
#       SBS        1
#       SBSPLUS    2
#       tvN        1
# 10    KBS1       1
# ...

# %%
df.groupby(['rank','category'])['category'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='rank,category'>
# C:\Users\2-12\Desktop\INSIGHT\venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\2-12\Desktop\INSIGHT\venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\2-12\Desktop\INSIGHT\venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 47560 (\N{HANGUL SYLLABLE MA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\2-12\Desktop\INSIGHT\venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\2-12\Desktop\INSIGHT\venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 45733 (\N{HANGUL SYLLABLE NEUNG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# ...

# %%
df.groupby(['day'])['day'].count()
# Out:
# day
# 금         9
# 금토        6
# 목         3
# 수        15
# 월         3
# 월화        3
# 월화수목금     8
# 일        13
# 토일       15
# 화         4
# Name: day, dtype: int64

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
df['day'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='day'>

# %%
df['time'].value_counts(bins=[1800,1900,2000,2100,2200,2300,2400], sort=False).plot(kind='bar')
# Out:
# <Axes: >

# %%
day_time = df.groupby(['day','time'])['time'].value_counts()

# %%
thu = pd.read_csv('금요일프로그램.csv')

# %%
thu.groupby(['category'])['category'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='category'>

# %%
fri = pd.read_csv('목요일프로그램.csv')

# %%
fri.groupby(['category'])['category'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='category'>

# %%
thu.sort_values(by='avg_view', axis=0, ascending=False)
# Out:
#    start_time   program_name channel    genre category  avg_view
# 1       20:30         수지맞은우리    KBS1    일일드라마      드라마     13.60
# 13      22:00           굿파트너     SBS    법정드라마      드라마     12.60
# 5       19:50            스캔들    KBS2    일일드라마      드라마      8.50
# 24      20:40          서진이네2     tvN     리얼리티       예능      7.90
# 2       21:00            뉴스9    KBS1       뉴스       뉴스      7.20
# 10      23:10          나혼자산다     MBC     리얼리티       예능      7.00
# 8       19:40          뉴스데스크     MBC       뉴스       뉴스      5.60
# 12      21:00        궁금한이야기Y     SBS       탐사    시사/교양      4.70
# 9       21:50      백설공주에게죽음을     MBC  미스터리드라마      드라마      4.50
# 11      19:50         SBS8뉴스     SBS       뉴스       뉴스      4.30
# 21      22:00          미스터로또    TV조선      트로트       예능      3.80
# 14      19:50           사건반장    JTBC       탐사    시사/교양      3.20
# 6       20:30       신상출시편스토랑    KBS2       음식       예능      3.00
# ...

# %%
fri.sort_values(by='avg_view', axis=0, ascending=False)
# Out:
#    start_time   program_name channel    genre category  avg_view
# 1       20:30         수지맞은우리    KBS1    일일드라마      드라마      13.8
# 5       19:50            스캔들    KBS2    일일드라마      드라마       8.5
# 2       21:00            뉴스9    KBS1       뉴스       뉴스       7.2
# 9       19:40          뉴스데스크     MBC       뉴스       뉴스       5.6
# 0       19:40         한국인의밥상    KBS1       음식    시사/교양       4.7
# 26      20:40        언니네산지직송     tvN     리얼리티       예능       4.6
# 12      19:50         SBS8뉴스     SBS       뉴스       뉴스       4.3
# 10      21:00          실화탐사대     MBC       탐사    시사/교양       4.0
# 23      22:00          미스쓰리랑    TV조선      트로트       예능       4.0
# 6       20:30      박원숙의같이삽시다    KBS2     리얼리티       예능       3.6
# 3       22:00         다큐인사이트    KBS1       정보    시사/교양       3.4
# 15      19:50           사건반장    JTBC     시사정보    시사/교양       3.2
# 13      21:00         과몰입인생사     SBS       역사       교양       3.1
# ...

# %%
thu['time'] = titanic.apply(lambda x : "남자" if x["sex"] == "male" 
                               else "여자" if x["age"] > 20 else '어린이', axis=1)
